# %% [markdown]
# <img src="img/itq.jpg" style="width:90px;"> <br>
# <h2 style="font-family: 'Times New Roman', Times, serif; text-align: center;">PAO25_26_30_Python_Variables_Cualitativas</h2>
# <h2 style="font-family: 'Times New Roman', Times, serif; text-align: center;">Marzo 30, 2026</h2>
# <p style="font-family: 'Times New Roman', Times, serif; font-weight:bold; font-size:16px;">
# </p>
#
# <img src="img/img2.png" alt="imagen" style="display:block; margin: 0 auto;"> </br>
#
# *Bryan Justin Antamba*
#
# <div style="font-family: 'Times New Roman', Times, serif;">
#
# ## **Variables Cualitativas**
# </div>

# %%
# Creación aleatoria de datos
import numpy as np
import random
import pandas as pd
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Master' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Master' 'Grado' 'Bachillerato' 'Secundaria' 'Master' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Doctorado' 'Secundaria' 'Bachillerato' 'Grado' 'Master' 'Secundaria'
#  'Grado' 'Master' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Secundaria' 'Doctorado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Master' 'Grado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Secundaria' 'Doctorado' 'Master'
#  'Master' 'Master' 'Bachillerato' 'Bachillerato' 'Doctorado' 'Master'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Master' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Doctorado' 'Grado' 'Secundaria' 'Secundaria'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Doctorado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Doctorado' 'Bachillerato'
#  'Bachillerato' 'Master' 'Master' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Master' 'Master' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Master'
#  'Secundaria' 'Secundaria' 'Master' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Secundaria' 'Master' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Doctorado'
#  'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Secundaria' 'Grado'
#  'Secundaria' 'Master' 'Secundaria' 'Grado' 'Master' 'Master' 'Secundaria'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Master' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Master' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Master'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Grado'
#  'Bachillerato' 'Master' 'Doctorado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Grado' 'Doctorado' 'Grado' 'Master' 'Secundaria' 'Master' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Master' 'Master' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Doctorado' 'Bachillerato' 'Master' 'Grado' 'Bachillerato' 'Doctorado'
#  'Grado' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Master' 'Secundaria' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Master' 'Secundaria'
#  'Grado' 'Grado' 'Master' 'Master' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Master' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Master' 'Doctorado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Doctorado' 'Bachillerato' 'Grado' 'Secundaria' 'Master' 'Grado' 'Grado'
#  'Secundaria' 'Master' 'Master' 'Grado' 'Master' 'Grado' 'Secundaria'
#  'Secundaria' 'Master' 'Secundaria' 'Grado' 'Doctorado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Master' 'Master' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Doctorado' 'Doctorado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Doctorado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Secundaria'
#  'Grado' 'Bachillerato' 'Master' 'Bachillerato' 'Master' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Master' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado'
#  'Grado' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Master'
#  'Doctorado' 'Secundaria' 'Grado']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información

# %%
df = pd.DataFrame({
   "Nivel_Estudios":  ["Bachillerato" , "Doctorado" , "Master" , "Grado" , "Secundaria"], 
    "Frecuencia":[172, 21, 52, 145, 110 ]
})

df.plot(x="Nivel_Estudios" , y="Frecuencia", kind="bar") 
plt.title("Grafico de Barras")

plt.xlabel("Nivel de Estudios")
plt.ylabel("Frecuencia")
plt.show()

# %%
df = pd.DataFrame({
   "Nivel_Estudios":  ["Bachillerato" , "Doctorado" , "Master" , "Grado" , "Secundaria"], 
    "Frecuencia":[172, 21, 52, 145, 110 ]
})
colores = ['red', 'blue', 'orange', 'green', 'cyan']
df.plot(
    x="Nivel_Estudios",
    y="Frecuencia",
    kind="pie",
    colors=colores,
    autopct='%1.2f%%',
    labels=df["Nivel_Estudios"],
    legend=False
    )

plt.title('Diagrama de sectores')
plt.show()

# %% [markdown]
# https://github.com/BryanAntamba/machine2026-PrimerParcial/blob/main/Machine%20E-learning%202/PrimerParcial/var_cualitativas.ipynb
