# %%
# Creación aleatoria de datos
import numpy as np
import random
import pandas as pd
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Grado' 'Master' 'Master' 'Doctorado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Master' 'Grado' 'Bachillerato' 'Master' 'Grado' 'Secundaria' 'Grado'
#  'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria'
#  'Doctorado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Doctorado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Master' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Master' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Master'
#  'Secundaria' 'Master' 'Secundaria' 'Grado' 'Bachillerato' 'Grado'
#  'Master' 'Grado' 'Secundaria' 'Secundaria' 'Doctorado' 'Master' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Master' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Master'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Grado' 'Master'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Doctorado' 'Secundaria' 'Grado' 'Secundaria' 'Master' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Master'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado'
#  'Grado' 'Grado' 'Master' 'Bachillerato' 'Doctorado' 'Grado' 'Secundaria'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Grado' 'Grado' 'Master'
#  'Doctorado' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Doctorado' 'Master' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Master' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Master'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Master'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Doctorado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Master' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Grado' 'Secundaria' 'Secundaria' 'Grado'
#  'Master' 'Secundaria' 'Master' 'Grado' 'Grado' 'Secundaria' 'Master'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Doctorado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Master' 'Bachillerato'
#  'Bachillerato' 'Master' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Master' 'Secundaria' 'Secundaria' 'Bachillerato' 'Master' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Secundaria'
#  'Grado' 'Secundaria' 'Grado' 'Grado' 'Grado' 'Grado' 'Master'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Master' 'Grado' 'Secundaria'
#  'Master' 'Bachillerato' 'Master' 'Grado' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Master' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Doctorado' 'Grado'
#  'Master' 'Grado' 'Grado' 'Doctorado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Doctorado' 'Master' 'Grado' 'Secundaria'
#  'Master' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Grado'
#  'Grado' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Master'
#  'Bachillerato' 'Master' 'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Grado'
#  'Master' 'Grado' 'Secundaria' 'Bachillerato' 'Master' 'Grado' 'Grado'
#  'Master' 'Secundaria' 'Bachillerato' 'Grado' 'Doctorado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Grado' 'Grado' 'Master' 'Grado' 'Bachillerato'
#  'Grado' 'Master' 'Master' 'Secundaria' 'Secundaria' 'Doctorado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Master' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado'
#  'Secundaria' 'Grado' 'Doctorado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Master' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Master' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información

# %%
df = pd.DataFrame({
   "Nivel_Estudios":  ["Bachillerato" , "Doctorado" , "Master" , "Grado" , "Secundaria"], 
    "Frecuencia":[172, 21, 52, 145, 110 ]
})

df.plot(x="Nivel_Estudios" , y="Frecuencia", kind="bar") 
plt.title("Grafico de Barras")

plt.xlabel("Nivel de Estudios")
plt.ylabel("Frecuencia")
plt.show()

# %%
df = pd.DataFrame({
   "Nivel_Estudios":  ["Bachillerato" , "Doctorado" , "Master" , "Grado" , "Secundaria"], 
    "Frecuencia":[172, 21, 52, 145, 110 ]
})
colores = ['red', 'blue', 'orange', 'green', 'cyan']
df.plot(
    x="Nivel_Estudios",
    y="Frecuencia",
    kind="pie",
    colors=colores,
    autopct='%1.2f%%',
    labels=df["Nivel_Estudios"],
    legend=False
    )

plt.title('Diagrama de sectores')
plt.show()
