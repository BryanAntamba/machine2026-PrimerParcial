# %% [markdown]
# <img src="img/itq.jpg" style="width:90px;"> <br>
# <h2 style="font-family: 'Times New Roman', Times, serif; text-align: center;">PAO25_26_27_Python_Ausentes</h2>
# <h2 style="font-family: 'Times New Roman', Times, serif; text-align: center;">Marzo 27, 2026</h2>
# <p style="font-family: 'Times New Roman', Times, serif; font-weight:bold; font-size:16px;">
# </p>
#
# <img src="img/img2.png" alt="imagen" style="display:block; margin: 0 auto;"> </br>
#
# *Bryan Justin Antamba*
#
# <div style="font-family: 'Times New Roman', Times, serif;">
#
# ## **Ausentes**
# </div>

# %%
import numpy as np
from sklearn.impute import SimpleImputer

# %%
# Carga de datos
X_train = [[1,      4], 
           [np.nan, 3], 
           [7,      8]]

# %%
# Limpieza de datos: imputación valores ausentes (modelo)
imputer = SimpleImputer(strategy='median') # Utilizamos la estrategia de la media

# Aplicar los métodos "fit" y "transform" para imputar los valores pérdidos de X_train
X_train_clean = imputer.fit_transform(X_train)
print(X_train_clean)
# Out:
# [[1. 4.]
#  [4. 3.]
#  [7. 8.]]

# %%
# Imputación de valores ausentes sobre el conjunto de test
X_test = [[np.nan, 10], 
          [6,      np.nan], 
          [8,      2]]

# Imputar los datos del conjunto de test
X_test_clean=imputer.transform(X_test)
print(X_test_clean)
# Out:
# [[ 4. 10.]
#  [ 6.  4.]
#  [ 8.  2.]]
