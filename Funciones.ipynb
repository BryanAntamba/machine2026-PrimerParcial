# %% [markdown]
# <img src="img/img1.png" alt="imagen" style="display:block; margin: 0 auto;"> <br>
# <h2 style="font-family: 'Times New Roman', Times, serif; text-align: center;">Introduccion</h2>
# <h2 style="font-family: 'Times New Roman', Times, serif; text-align: center;">Enero 9, 2026</h2>
# <img src="img/img2.png" alt="imagen" style="display:block; margin: 0 auto;"> </br>
#
# *Bryan Justin Antamba*
# <h3 style="font-family: 'Times New Roman', Times, serif;">2  Introduccion a Python</h3> <br>
# <div style="font-family: 'Times New Roman', Times, serif;">
#
# ## **2 Introducción a Python**
